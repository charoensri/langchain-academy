# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/time-travel.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239536-lesson-5-time-travel)

# %% [markdown]
# # Time travel
#
# ## Review
#
# We discussed motivations for human-in-the-loop:
#
# (1) `Approval` - We can interrupt our agent, surface state to a user, and allow the user to accept an action
#
# (2) `Debugging` - We can rewind the graph to reproduce or avoid issues
#
# (3) `Editing` - You can modify the state
#
# We showed how breakpoints can stop the graph at specific nodes or allow the graph to dynamically interrupt itself.
#
# Then we showed how to proceed with human approval or directly edit the graph state with human feedback.
#
# ## Goals
#
# Now, let's show how LangGraph [supports debugging](https://docs.langchain.com/oss/python/langgraph/use-time-travel) by viewing, re-playing, and even forking from past states.
#
# We call this `time travel`.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk langgraph-prebuilt langchain_Ollama

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# Let's build our agent.

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama

def multiply(a: int, b: int) -> int:
    """Multiply a and b.

    Args:
        a: first int
        b: second int
    """
    return a * b

# This will be a tool
def add(a: int, b: int) -> int:
    """Adds a and b.

    Args:
        a: first int
        b: second int
    """
    return a + b

def divide(a: int, b: int) -> float:
    """Divide a by b.

    Args:
        a: first int
        b: second int
    """
    return a / b

tools = [add, multiply, divide]
#llm = ChatOpenAI(model="gpt-4o")
llm = ChatOllama(model="llama3.2")
llm_with_tools = llm.bind_tools(tools)

# %%
from IPython.display import Image, display

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import tools_condition, ToolNode

from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# System message
sys_msg = SystemMessage(content="You are a helpful assistant tasked with performing arithmetic on a set of inputs.")

# Node
def assistant(state: MessagesState):
   return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# Graph
builder = StateGraph(MessagesState)

# Define nodes: these do the work
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

# Define edges: these determine the control flow
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", "assistant")

memory = MemorySaver()
graph = builder.compile(checkpointer=MemorySaver())

# Show
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# Let's run it, as before.

# %%
# Input
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}

# Thread
thread = {"configurable": {"thread_id": "1"}}

# Run the graph until the first interruption
for event in graph.stream(initial_input, thread, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (798e2027-0279-4355-8897-e526bca13870)
#  Call ID: 798e2027-0279-4355-8897-e526bca13870
#   Args:
#     b: 3
#     a: 2
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The result of multiplying 2 and 3 is 6.

# %% [markdown]
# ## Browsing History
#
# We can use `get_state` to look at the **current** state of our graph, given the `thread_id`!

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870'), AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.7245387Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512113600, 'load_duration': 283466300, 'prompt_eval_count': 107, 'prompt_eval_duration': 22740000, 'eval_count': 14, 'eval_duration': 186643000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab30-36b2-7af2-a4e4-b3260d8de2e6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-f28a-6c1c-8003-8e1a5e03fca2'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-09T07:02:04.726982+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed9b-6f92-8002-6f8c6b5aa02e'}}, tasks=(), interrupts=())

# %% [markdown]
# We can also browse the state history of our agent.
#
# `get_state_history` lets us get the state at all prior steps.

# %%
all_states = [s for s in graph.get_state_history(thread)]

# %%
len(all_states)
# Out:
# 5

# %%
all_states
# Out:
# [StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870'), AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.7245387Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512113600, 'load_duration': 283466300, 'prompt_eval_count': 107, 'prompt_eval_duration': 22740000, 'eval_count': 14, 'eval_duration': 186643000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab30-36b2-7af2-a4e4-b3260d8de2e6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-f28a-6c1c-8003-8e1a5e03fca2'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-09T07:02:04.726982+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed9b-6f92-8002-6f8c6b5aa02e'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed9b-6f92-8002-6f8c6b5aa02e'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-09T07:02:04.209747+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed91-62bb-8001-966ecdd56182'}}, tasks=(PregelTask(id='5799084c-faa8-633a-2a55-5387df60897e', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.7245387Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512113600, 'load_duration': 283466300, 'prompt_eval_count': 107, 'prompt_eval_duration': 22740000, 'eval_count': 14, 'eval_duration': 186643000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab30-36b2-7af2-a4e4-b3260d8de2e6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319})]}, next=('tools',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed91-62bb-8001-966ecdd56182'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-09T07:02:04.205314+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}, tasks=(PregelTask(id='6e3379bf-dd4b-4388-a0f0-c81f4ee94113', name='tools', path=('__pregel_pull', 'tools'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870')]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-09T07:01:47.579752+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f00-6693-bfff-d1169b0e8859'}}, tasks=(PregelTask(id='adf6b24d-c879-0674-fc41-4cd9e93e5a9f', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319})]}),), interrupts=()),
#  StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f00-6693-bfff-d1169b0e8859'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-09T07:01:47.578528+00:00', parent_config=None, tasks=(PregelTask(id='d8925b62-762d-1eaf-afb5-47d019c6d537', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')}),), interrupts=())]

# %% [markdown]
# The first element is the current state, just as we got from `get_state`.

# %%
all_states[0] #first! snapshort
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870'), AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.7245387Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512113600, 'load_duration': 283466300, 'prompt_eval_count': 107, 'prompt_eval_duration': 22740000, 'eval_count': 14, 'eval_duration': 186643000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab30-36b2-7af2-a4e4-b3260d8de2e6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-f28a-6c1c-8003-8e1a5e03fca2'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-09T07:02:04.726982+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed9b-6f92-8002-6f8c6b5aa02e'}}, tasks=(), interrupts=())

# %%
all_states[-2]
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-09T07:01:47.579752+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f00-6693-bfff-d1169b0e8859'}}, tasks=(PregelTask(id='adf6b24d-c879-0674-fc41-4cd9e93e5a9f', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319})]}),), interrupts=())

# %% [markdown]
# Everything above we can visualize here:
#
# ![fig1.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038211b544898570be3_time-travel1.png)

# %% [markdown]
# ## Replaying
#
# We can re-run our agent from any of the prior steps.
#
# ![fig2.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038a0bd34b541c78fb8_time-travel2.png)

# %% [markdown]
# Let's look back at the step that recieved human input!

# %%
to_replay = all_states[-2]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-09T07:01:47.579752+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f00-6693-bfff-d1169b0e8859'}}, tasks=(PregelTask(id='adf6b24d-c879-0674-fc41-4cd9e93e5a9f', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319})]}),), interrupts=())

# %% [markdown]
# Look at the state.

# %%
to_replay.values
# Out:
# {'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]}

# %% [markdown]
# We can see the next node to call.

# %%
to_replay.next
# Out:
# ('assistant',)

# %% [markdown]
# We also get the config, which tells us the `checkpoint_id` as well as the `thread_id`.

# %%
to_replay.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}

# %% [markdown]
# To replay from here, we simply pass the config back to the agent!
#
# The graph knows that this checkpoint has aleady been executed.
#
# It just re-plays from this checkpoint!

# %%
for event in graph.stream(None, to_replay.config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (8807c707-5ab5-4885-be8d-3359055d19d2)
#  Call ID: 8807c707-5ab5-4885-be8d-3359055d19d2
#   Args:
#     a: 2
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The product of 2 and 3 is 6.

# %%
all_states[0]
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870'), AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.7245387Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512113600, 'load_duration': 283466300, 'prompt_eval_count': 107, 'prompt_eval_duration': 22740000, 'eval_count': 14, 'eval_duration': 186643000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab30-36b2-7af2-a4e4-b3260d8de2e6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-f28a-6c1c-8003-8e1a5e03fca2'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-09T07:02:04.726982+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed9b-6f92-8002-6f8c6b5aa02e'}}, tasks=(), interrupts=())

# %% [markdown]
# Now, we can see our current state after the agent re-ran.

# %%
all_states
# Out:
# [StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870'), AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.7245387Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512113600, 'load_duration': 283466300, 'prompt_eval_count': 107, 'prompt_eval_duration': 22740000, 'eval_count': 14, 'eval_duration': 186643000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab30-36b2-7af2-a4e4-b3260d8de2e6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-f28a-6c1c-8003-8e1a5e03fca2'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-09T07:02:04.726982+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed9b-6f92-8002-6f8c6b5aa02e'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed9b-6f92-8002-6f8c6b5aa02e'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-09T07:02:04.209747+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed91-62bb-8001-966ecdd56182'}}, tasks=(PregelTask(id='5799084c-faa8-633a-2a55-5387df60897e', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.7245387Z', 'done': True, 'done_reason': 'stop', 'total_duration': 512113600, 'load_duration': 283466300, 'prompt_eval_count': 107, 'prompt_eval_duration': 22740000, 'eval_count': 14, 'eval_duration': 186643000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab30-36b2-7af2-a4e4-b3260d8de2e6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319})]}, next=('tools',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-ed91-62bb-8001-966ecdd56182'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-09T07:02:04.205314+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}, tasks=(PregelTask(id='6e3379bf-dd4b-4388-a0f0-c81f4ee94113', name='tools', path=('__pregel_pull', 'tools'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content='6', name='multiply', id='05d3e856-a72d-4382-a8d1-9092158dffe3', tool_call_id='798e2027-0279-4355-8897-e526bca13870')]}),), interrupts=()),
#  StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-09T07:01:47.579752+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f00-6693-bfff-d1169b0e8859'}}, tasks=(PregelTask(id='adf6b24d-c879-0674-fc41-4cd9e93e5a9f', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:02:04.1920075Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16605567100, 'load_duration': 16086626200, 'prompt_eval_count': 297, 'prompt_eval_duration': 158245000, 'eval_count': 22, 'eval_duration': 353338000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab2f-f5be-7422-894e-a2c8c59bb880-0', tool_calls=[{'name': 'multiply', 'args': {'b': '3', 'a': '2'}, 'id': '798e2027-0279-4355-8897-e526bca13870', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319})]}),), interrupts=()),
#  StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f00-6693-bfff-d1169b0e8859'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-09T07:01:47.578528+00:00', parent_config=None, tasks=(PregelTask(id='d8925b62-762d-1eaf-afb5-47d019c6d537', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')}),), interrupts=())]

# %% [markdown]
# ## Forking
#
# What if we want to run from that same step, but with a different input.
#
# This is forking.
#
# ![fig3.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038f89f2d847ee5c336_time-travel3.png)

# %%
to_fork = all_states[-2]
to_fork.values["messages"]
# Out:
# [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]

# %% [markdown]
# Again, we have the config.

# %%
to_fork.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}

# %% [markdown]
# Let's modify the state at this checkpoint.
#
# We can just run `update_state` with the `checkpoint_id` supplied.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!
#
# So, to overwrite the the message, we just supply the message ID, which we have `to_fork.values["messages"].id`.

# %%
fork_config = graph.update_state(
    to_fork.config,
    {"messages": [HumanMessage(content='Multiply 5 and 3', 
                               id=to_fork.values["messages"][0].id)]},
)

# %%
fork_config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f163d75-8795-60ad-8001-fed174ebec8d'}}

# %% [markdown]
# This creates a new, forked checkpoint.
#
# But, the metadata - e.g., where to go next - is perserved!
#
# We can see the current state of our agent has been updated with our fork.

# %%
all_states = [state for state in graph.get_state_history(thread) ]
all_states[0].values["messages"]
# Out:
# [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d75-8795-60ad-8001-fed174ebec8d'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-06-09T07:46:37.865987+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d11-4f03-666f-8000-400007d18b83'}}, tasks=(PregelTask(id='f878e24d-fafa-e1f1-26fb-5e27cb5e8451', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %% [markdown]
# Now, when we stream, the graph knows this checkpoint has never been executed.
#
# So, the graph runs, rather than simply re-playing.

# %%
for event in graph.stream(None, fork_config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 5 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (3b510d5a-07d4-4fbe-b35b-f77a0d4ec7ac)
#  Call ID: 3b510d5a-07d4-4fbe-b35b-f77a0d4ec7ac
#   Args:
#     a: 5
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 15
# ================================== Ai Message ==================================
#
# The result of multiplying 5 and 3 is 15.

# %% [markdown]
# Now, we can see the current state is the end of our agent run.

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='852038f2-8d77-43b3-a4c2-80afd5627c47'), AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:52:03.8178367Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7559387000, 'load_duration': 7024505600, 'prompt_eval_count': 297, 'prompt_eval_duration': 199757000, 'eval_count': 22, 'eval_duration': 326307000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab5d-de60-7ad3-b02a-867dce679cda-0', tool_calls=[{'name': 'multiply', 'args': {'a': '5', 'b': '3'}, 'id': '3b510d5a-07d4-4fbe-b35b-f77a0d4ec7ac', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 297, 'output_tokens': 22, 'total_tokens': 319}), ToolMessage(content='15', name='multiply', id='1aa90f0e-64ff-401a-8446-32f218f764b7', tool_call_id='3b510d5a-07d4-4fbe-b35b-f77a0d4ec7ac'), AIMessage(content='The result of multiplying 5 and 3 is 15.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-09T07:52:04.6273559Z', 'done': True, 'done_reason': 'stop', 'total_duration': 768232300, 'load_duration': 507659900, 'prompt_eval_count': 107, 'prompt_eval_duration': 26128000, 'eval_count': 14, 'eval_duration': 198385000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019eab5d-fc0a-7ac0-814e-d8f5d374d852-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 107, 'output_tokens': 14, 'total_tokens': 121})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d81-b3f1-673b-8004-15a26c7faf85'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-09T07:52:04.640118+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163d81-ac5c-6d5e-8003-37847808a95a'}}, tasks=(), interrupts=())

# %% [markdown]
# ### Time travel with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# We connect to it via the SDK and show how the LangGraph API [supports time travel](https://docs.langchain.com/langsmith/human-in-the-loop-time-travel).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client
client = get_client(url="http://127.0.0.1:2024")

# %% [markdown]
# #### Re-playing
#
# Let's run our agent streaming `updates` to the state of the graph after each node is called.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id = "agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:54:56.7859608Z', 'done': True, 'done_reason': 'stop', 'total_duration': 43933302100, 'load_duration': 38888809800, 'prompt_eval_count': 231, 'prompt_eval_duration': 1416020000, 'eval_count': 35, 'eval_duration': 3604395000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eaca9-8aef-79d1-8b7f-df23ad5289a9-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '2ee5508d-8178-4377-9bef-de9b12429c50', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 35, 'total_tokens': 266}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'f7a4888b-0bb4-4ecb-be71-d7667e8f5e34', 'tool_call_id': '2ee5508d-8178-4377-9bef-de9b12429c50', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 2 by 3 is **6**.', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:55:04.5675796Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7739951500, 'load_duration': 740453200, 'prompt_eval_count': 263, 'prompt_eval_duration': 1142528000, 'eval_count': 42, 'eval_duration': 5848807000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacaa-36b9-7361-936f-de5797fd1772-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 42, 'total_tokens': 305}}

# %% [markdown]
# Now, let's look at **replaying** from a specified checkpoint.
#
# We simply need to pass the `checkpoint_id`.

# %%
states = await client.threads.get_history(thread['thread_id'])
to_replay = states[-2]
to_replay
# Out:
# {'values': {'messages': [{'content': 'Multiply 2 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': 'fdf83d2e-9b73-4819-957d-9595da2f5255'}]},
#  'next': ['assistant'],
#  'tasks': [{'id': '69ef34e9-efd6-ee7a-8a71-04edccff675f',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': {'messages': [{'content': '',
#       'additional_kwargs': {},
#       'response_metadata': {'model': 'gpt-oss:20b',
#        'created_at': '2026-06-09T13:54:56.7859608Z',
#        'done': True,
#        'done_reason': 'stop',
#        'total_duration': 43933302100,
#        'load_duration': 38888809800,
#        'prompt_eval_count': 231,
#        'prompt_eval_duration': 1416020000,
#        'eval_count': 35,
#        'eval_duration': 3604395000,
#        'logprobs': None,
#        'model_name': 'gpt-oss:20b',
#        'model_provider': 'ollama'},
#       'type': 'ai',
#       'name': None,
#       'id': 'lc_run--019eaca9-8aef-79d1-8b7f-df23ad5289a9-0',
#       'tool_calls': [{'name': 'multiply',
#         'args': {'a': 2, 'b': 3},
#         'id': '2ee5508d-8178-4377-9bef-de9b12429c50',
#         'type': 'tool_call'}],
#       'invalid_tool_calls': [],
#       'usage_metadata': {'input_tokens': 231,
#        'output_tokens': 35,
#        'total_tokens': 266}}]}}],
#  'metadata': {'graph_id': 'agent',
#   'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'user_id': '',
#   'created_by': 'system',
#   'run_attempt': 1,
#   'langgraph_version': '1.2.4',
#   'langgraph_api_version': '0.8.7',
#   'langgraph_plan': 'enterprise',
#   'langgraph_host': 'self-hosted',
#   'langgraph_api_url': 'http://127.0.0.1:2024',
#   'run_id': '019eaca9-8686-7ad0-95f1-492a3a855db3',
#   'thread_id': '019eaca9-867d-72c1-af4d-55e6b34fb1b9',
#   'source': 'loop',
#   'step': 0,
#   'parents': {},
#   'langgraph_auth_user_id': '',
#   'langgraph_request_id': '22508579-1c61-4b4e-aab0-4d37d7138d9c'},
#  'created_at': '2026-06-09T13:54:12.844751+00:00',
#  'checkpoint': {'checkpoint_id': '1f1640ab-2440-60db-8000-14607902d41e',
#   'thread_id': '019eaca9-867d-72c1-af4d-55e6b34fb1b9',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f1640ab-243b-64a8-bfff-f49b28cc0472',
#   'thread_id': '019eaca9-867d-72c1-af4d-55e6b34fb1b9',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f1640ab-2440-60db-8000-14607902d41e',
#  'parent_checkpoint_id': '1f1640ab-243b-64a8-bfff-f49b28cc0472'}

# %% [markdown]
# Let's stream with `stream_mode="values"` to see the full state at every node as we replay.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="values",
    checkpoint_id=to_replay['checkpoint_id']
):      
    print(f"Receiving new event of type: {chunk.event}...")
    print(chunk.data)
    print("\n\n")
# Out:
# Receiving new event of type: metadata...
# {'run_id': '019eacab-cb95-76c1-9444-1e1725e51df5', 'attempt': 1}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'fdf83d2e-9b73-4819-957d-9595da2f5255'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'fdf83d2e-9b73-4819-957d-9595da2f5255'}, {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:56:45.96194Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4609526100, 'load_duration': 632177000, 'prompt_eval_count': 231, 'prompt_eval_duration': 532307000, 'eval_count': 49, 'eval_duration': 3434251000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacab-cf04-7750-ada3-494fa2cb4a41-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '68b4403a-790d-4182-ac68-a51fd231931d', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 49, 'total_tokens': 280}}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'fdf83d2e-9b73-4819-957d-9595da2f5255'}, {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:56:45.96194Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4609526100, 'load_duration': 632177000, 'prompt_eval_count': 231, 'prompt_eval_duration': 532307000, 'eval_count': 49, 'eval_duration': 3434251000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacab-cf04-7750-ada3-494fa2cb4a41-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '68b4403a-790d-4182-ac68-a51fd231931d', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 49, 'total_tokens': 280}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e071983f-0c3e-48ee-8649-08c64744c18d', 'tool_call_id': '68b4403a-790d-4182-ac68-a51fd231931d', 'artifact': None, 'status': 'success'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'fdf83d2e-9b73-4819-957d-9595da2f5255'}, {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:56:45.96194Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4609526100, 'load_duration': 632177000, 'prompt_eval_count': 231, 'prompt_eval_duration': 532307000, 'eval_count': 49, 'eval_duration': 3434251000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacab-cf04-7750-ada3-494fa2cb4a41-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '68b4403a-790d-4182-ac68-a51fd231931d', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 49, 'total_tokens': 280}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e071983f-0c3e-48ee-8649-08c64744c18d', 'tool_call_id': '68b4403a-790d-4182-ac68-a51fd231931d', 'artifact': None, 'status': 'success'}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:56:49.8962879Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3889404200, 'load_duration': 571362900, 'prompt_eval_count': 263, 'prompt_eval_duration': 944118000, 'eval_count': 24, 'eval_duration': 2363540000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacab-e135-7662-a8a2-eaf666bd8217-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 24, 'total_tokens': 287}}]}

# %% [markdown]
# We can all view this as streaming only `updates` to state made by the nodes that we reply.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=to_replay['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:59:15.5092931Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6135413500, 'load_duration': 587735800, 'prompt_eval_count': 231, 'prompt_eval_duration': 553406000, 'eval_count': 58, 'eval_duration': 4981993000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacae-113b-7363-ba68-32c720a29b39-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '53bb7429-e6eb-4dd2-b4a2-6d799d8d68d5', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 58, 'total_tokens': 289}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '01c632f3-e13d-4151-8ffc-96f969e28e24', 'tool_call_id': '53bb7429-e6eb-4dd2-b4a2-6d799d8d68d5', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The product of\u202f2\u202fand\u202f3 is **6**.', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T13:59:21.4949041Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5929867700, 'load_duration': 825720500, 'prompt_eval_count': 263, 'prompt_eval_duration': 1195884000, 'eval_count': 32, 'eval_duration': 3879939000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacae-2969-7211-afb5-d1026bc6e24f-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 32, 'total_tokens': 295}}

# %% [markdown]
# #### Forking
#
# Now, let's look at forking.
#
# Let's get the same step as we worked with above, the human input.
#
# Let's create a new thread with our agent.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T14:01:50.1850758Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4978961700, 'load_duration': 580653300, 'prompt_eval_count': 231, 'prompt_eval_duration': 1149308000, 'eval_count': 50, 'eval_duration': 3214801000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacb0-71f3-7e30-acc6-790e3a97ce56-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '688c7973-6fba-4f58-a107-eeb2a44093fd', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 50, 'total_tokens': 281}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '9b57a9b1-e13b-4a94-a067-a32c7b6bde2e', 'tool_call_id': '688c7973-6fba-4f58-a107-eeb2a44093fd', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 2 and 3 is **6**.', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T14:01:56.8361153Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6614073800, 'load_duration': 690294100, 'prompt_eval_count': 263, 'prompt_eval_duration': 1058000000, 'eval_count': 43, 'eval_duration': 4851615000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacb0-858c-7670-932d-4f44fff688a7-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 43, 'total_tokens': 306}}

# %%
states = await client.threads.get_history(thread['thread_id'])
to_fork = states[-2]
to_fork['values']
# Out:
# {'messages': [{'content': 'Multiply 2 and 3',
#    'additional_kwargs': {},
#    'response_metadata': {},
#    'type': 'human',
#    'name': None,
#    'id': '2463c6ce-b1ba-415b-8899-2374d1dd338b'}]}

# %%
to_fork['values']['messages'][0]['id']
# Out:
# '2463c6ce-b1ba-415b-8899-2374d1dd338b'

# %%
to_fork['next']
# Out:
# ['assistant']

# %%
to_fork['checkpoint_id']
# Out:
# '1f1640bb-fe45-6da6-8000-e8345df1b619'

# %%
to_fork
# Out:
# {'values': {'messages': [{'content': 'Multiply 2 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': '2463c6ce-b1ba-415b-8899-2374d1dd338b'}]},
#  'next': ['assistant'],
#  'tasks': [{'id': '9af5f597-fee4-1903-f03d-4e8b95d88171',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': {'messages': [{'content': '',
#       'additional_kwargs': {},
#       'response_metadata': {'model': 'gpt-oss:20b',
#        'created_at': '2026-06-09T14:01:50.1850758Z',
#        'done': True,
#        'done_reason': 'stop',
#        'total_duration': 4978961700,
#        'load_duration': 580653300,
#        'prompt_eval_count': 231,
#        'prompt_eval_duration': 1149308000,
#        'eval_count': 50,
#        'eval_duration': 3214801000,
#        'logprobs': None,
#        'model_name': 'gpt-oss:20b',
#        'model_provider': 'ollama'},
#       'type': 'ai',
#       'name': None,
#       'id': 'lc_run--019eacb0-71f3-7e30-acc6-790e3a97ce56-0',
#       'tool_calls': [{'name': 'multiply',
#         'args': {'a': 2, 'b': 3},
#         'id': '688c7973-6fba-4f58-a107-eeb2a44093fd',
#         'type': 'tool_call'}],
#       'invalid_tool_calls': [],
#       'usage_metadata': {'input_tokens': 231,
#        'output_tokens': 50,
#        'total_tokens': 281}}]}}],
#  'metadata': {'graph_id': 'agent',
#   'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'user_id': '',
#   'created_by': 'system',
#   'run_attempt': 1,
#   'langgraph_version': '1.2.4',
#   'langgraph_api_version': '0.8.7',
#   'langgraph_plan': 'enterprise',
#   'langgraph_host': 'self-hosted',
#   'langgraph_api_url': 'http://127.0.0.1:2024',
#   'run_id': '019eacb0-6ef0-7421-8359-d7141f7f0904',
#   'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'source': 'loop',
#   'step': 0,
#   'parents': {},
#   'langgraph_auth_user_id': '',
#   'langgraph_request_id': '7d6665f3-ac6c-4e50-a0e5-7065a026868e'},
#  'created_at': '2026-06-09T14:01:45.202825+00:00',
#  'checkpoint': {'checkpoint_id': '1f1640bb-fe45-6da6-8000-e8345df1b619',
#   'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f1640bb-fe44-637c-bfff-d8df8fa111f1',
#   'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f1640bb-fe45-6da6-8000-e8345df1b619',
#  'parent_checkpoint_id': '1f1640bb-fe44-637c-bfff-d8df8fa111f1'}

# %% [markdown]
# Let's edit the state.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!

# %%
forked_input = {"messages": HumanMessage(content="Multiply 3 and 3",
                                         id=to_fork['values']['messages'][0]['id'])}

forked_config = await client.threads.update_state(
    thread["thread_id"],
    forked_input,
    checkpoint_id=to_fork['checkpoint_id']
)

# %%
forked_config
# Out:
# {'checkpoint': {'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1640c5-3d1b-690f-8001-a14f060df891'},
#  'configurable': {'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1640c5-3d1b-690f-8001-a14f060df891'},
#  'checkpoint_id': '1f1640c5-3d1b-690f-8001-a14f060df891'}

# %%
states = await client.threads.get_history(thread['thread_id'])
states[0]
# Out:
# {'values': {'messages': [{'content': 'Multiply 3 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': '2463c6ce-b1ba-415b-8899-2374d1dd338b'}]},
#  'next': ['assistant'],
#  'tasks': [{'id': '336b4a4e-5df5-21ba-5e3a-7afa0bb6ad1b',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': None}],
#  'metadata': {'graph_id': 'agent',
#   'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'checkpoint_id': '1f1640bb-fe45-6da6-8000-e8345df1b619',
#   'source': 'update',
#   'step': 1,
#   'parents': {}},
#  'created_at': '2026-06-09T14:05:53.383424+00:00',
#  'checkpoint': {'checkpoint_id': '1f1640c5-3d1b-690f-8001-a14f060df891',
#   'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f1640bb-fe45-6da6-8000-e8345df1b619',
#   'thread_id': '019eacb0-6ee9-7b42-8cfb-e6d48c15f4f4',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f1640c5-3d1b-690f-8001-a14f060df891',
#  'parent_checkpoint_id': '1f1640bb-fe45-6da6-8000-e8345df1b619'}

# %% [markdown]
# To rerun, we pass in the `checkpoint_id`.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=forked_config['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T14:07:31.7007639Z', 'done': True, 'done_reason': 'stop', 'total_duration': 30479588700, 'load_duration': 26522667600, 'prompt_eval_count': 231, 'prompt_eval_duration': 1318451000, 'eval_count': 35, 'eval_duration': 2620057000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacb5-4462-7042-a33e-ecbbfcff7f18-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 3, 'b': 3}, 'id': '6b9ca861-26bc-4e73-9b85-20a6c4bb01ae', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 35, 'total_tokens': 266}}
# --------------------Tools Node--------------------
# {'content': '9', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '53c341b8-6f24-4597-a866-b8e240c63b96', 'tool_call_id': '6b9ca861-26bc-4e73-9b85-20a6c4bb01ae', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The product of\u202f3\u202fand\u202f3 is **9**.', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-09T14:07:38.5884944Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6830255700, 'load_duration': 669958800, 'prompt_eval_count': 263, 'prompt_eval_duration': 1019530000, 'eval_count': 49, 'eval_duration': 5127408000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019eacb5-bba0-74f0-a5a1-6bb5f0075671-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 49, 'total_tokens': 312}}

# %% [markdown]
# ### LangGraph Studio
#
# Let's look at forking in the Studio UI with our `agent`, which uses `module-1/studio/agent.py` set in `module-1/studio/langgraph.json`.
