# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/streaming-interruption.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239464-lesson-1-streaming)

# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install -U langgraph langchain_openai langchain_ollama langgraph_sdk
#%pip install --quiet -U langgraph langchain_openai langgraph_sdk
# Out:
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://docs.langchain.com/oss/python/langgraph/streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display
from typing import Literal

from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
#model = ChatOpenAI(model="gpt-4o", temperature=0)
model = ChatOllama(model="llama3.2", temperature=0) 


# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State)-> Literal ["summarize_conversation",END]:
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state) for graph state.
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content="Hi Lance! It's nice to meet you. Is there something I can help you with, or would you like to chat?", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-06T13:32:49.4354486Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9014208100, 'load_duration': 8471628500, 'prompt_eval_count': 30, 'prompt_eval_duration': 140674000, 'eval_count': 27, 'eval_duration': 392278000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019e9d22-be64-7f93-b39d-39d65e9c1cc9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 27, 'total_tokens': 57})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hi Lance! How's it going? What can I do for you today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi Lance! It's nice to meet you. Is there something I can help you with, or would you like to chat?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://docs.langchain.com/oss/python/langchain/models#advanced-streaming-topics:streaming-events), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_end. Name: ChatOllama
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' professional', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' American', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' football', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' based', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Santa', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' They', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' member', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' League', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='NFL', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' play', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' home', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' games', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Levi', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Santa', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='History', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' were', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' founded', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' October', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='30', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='194', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='6', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' charter', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' member', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' All', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-Americ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='a', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Conference', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='AA', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='FC', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=').', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' was', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' originally', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' known', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Dem', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ons', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' changed', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' its', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' name', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='195', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' In', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='195', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' AA', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='FC', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' merged', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' League', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='NFL', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='),', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' became', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' an', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Ch', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ampionship', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' five', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' championships', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XVI', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='):', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' defeated', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Cincinnati', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bengals', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='26', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='21', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' X', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='IX', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='):', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' defeated', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Miami', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Dolphins', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='38', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='16', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XX', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='III', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='):', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' defeated', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Cincinnati', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bengals', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='20', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='16', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XX', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='IV', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='199', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='):', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' defeated', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Denver', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Broncos', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='55', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='10', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XX', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='IX', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='199', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='):', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' defeated', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Diego', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Chargers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='26', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Not', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='able', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Players', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# ...
# {'chunk': AIMessageChunk(content='osa', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' defensive', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' end', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='St', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='adium', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' play', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' home', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' games', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' at', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Levi', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content="'s", additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Stadium', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' which', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' seating', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' capacity', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' over', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='68', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='000', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' stadium', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' was', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' opened', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='201', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' features', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' state', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-of', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-art', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' amenities', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' technology', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Overall', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='49', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' proud', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' stor', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ied', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' franchise', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' rich', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' history', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' success', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' field', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-06-06T13:35:00.2685321Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8132471100, 'load_duration': 358682600, 'prompt_eval_count': 34, 'prompt_eval_duration': 264964000, 'eval_count': 504, 'eval_duration': 7434996000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 504, 'total_tokens': 538}, tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--019e9d24-c0e1-7870-b565-2ea613552c44', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[], chunk_position='last')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# The| San| Francisco| |49|ers| are| a| professional| American| football| team| based| in| Santa| Clara|,| California|.| They| are| a| member| of| the| National| Football| League| (|NFL|)| and| play| their| home| games| at| Levi|'s| Stadium| in| Santa| Clara|.
#
# |**|History|**
#
# |The| |49|ers| were| founded| on| October| |30|,| |194|6|,| as| a| charter| member| of| the| All|-Americ|a| Football| Conference| (|AA|FC|).| The| team| was| originally| known| as| the| San| Francisco| Dem|ons| but| changed| its| name| to| the| |49|ers| in| |195|0|.| In| |195|0|,| the| AA|FC| merged| with| the| National| Football| League| (|NFL|),| and| the| |49|ers| became| an| NFL| team|.
#
# |**|Ch|ampionship|s|**
#
# |The| |49|ers| have| won| five| Super| Bowl| championships|:
#
# |1|.| Super| Bowl| XVI| (|198|2|):| defeated| the| Cincinnati| Bengals| |26|-|21|
# |2|.| Super| Bowl| X|IX| (|198|5|):| defeated| the| Miami| Dolphins| |38|-|16|
# |3|.| Super| Bowl| XX|III| (|198|9|):| defeated| the| Cincinnati| Bengals| |20|-|16|
# |4|.| Super| Bowl| XX|IV| (|199|0|):| defeated| the| Denver| Broncos| |55|-|10|
# |5|.| Super| Bowl| XX|IX| (|199|5|):| defeated| the| San| Diego| Chargers| |49|-|26|
#
# |**|Not|able| Players|**
#
# |Some| notable| players| in| |49|ers| history| include|:
#
# |1|.| Joe| Montana|:| quarterback| who| led| the| team| to| four| Super| Bowl| championships| and| is| considered| one| of| the| greatest| quarterbacks| in| NFL| history|.
# |2|.| Jerry| Rice|:| wide| receiver| who| holds| numerous| NFL| records|,| including| most| career| receptions|,| yards|,| and| touchdowns|.
# |3|.| Steve| Young|:| quarterback| who| won| the| Super| Bowl| XX|IX| MVP| award| and| was| a| two|-time| NFL| MVP|.
# |4|.| Patrick| Willis|:| linebacker| who| played| for| the| |49|ers| from| |200|7| to| |201|4| and| was| a| six|-time| Pro| Bowl| selection|.
#
# |**|Current| Team|**
#
# |The| current| team| is| led| by| head| coach| Kyle| Shan|ahan|,| who| took| over| in| |201|8|.| The| |49|ers| have| a| strong| roster| with| players| such| as|:
#
# |1|.| Jimmy| Gar|opp|olo|:| quarterback|
# |2|.| Dee|bo| Samuel|:| wide| receiver|
# |3|.| George| K|ittle|:| tight| end|
# |4|.| Nick| B|osa|:| defensive| end|
#
# |**|St|adium|**
#
# |The| |49|ers| play| their| home| games| at| Levi|'s| Stadium|,| which| has| a| seating| capacity| of| over| |68|,|000|.| The| stadium| was| opened| in| |201|4| and| features| state|-of|-the|-art| amenities| and| technology|.
#
# |Overall|,| the| San| Francisco| |49|ers| are| a| proud| and| stor|ied| franchise| with| a| rich| history| of| success| on| the| field|.|||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# The LangGraph API  [supports editing graph state](https://docs.langchain.com/langsmith/add-human-in-the-loop).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()
print(assistants)
# Out:
# [{'assistant_id': '6f6fce9a-b777-529d-9699-dd340ddec86c', 'graph_id': 'dynamic_breakpoints', 'config': {}, 'context': {}, 'metadata': {'created_by': 'system'}, 'name': 'dynamic_breakpoints', 'created_at': '2026-06-07T11:17:38.142530+00:00', 'updated_at': '2026-06-07T11:17:38.142530+00:00', 'version': 1, 'description': None}, {'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca', 'graph_id': 'agent', 'config': {}, 'context': {}, 'metadata': {'created_by': 'system'}, 'name': 'agent', 'created_at': '2026-06-06T11:38:43.074841+00:00', 'updated_at': '2026-06-06T11:38:43.074841+00:00', 'version': 1, 'description': None}]

# %% [markdown]
# Let's [stream `values`](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '019ea1ce-7d86-74a0-9944-bb3b82b5d440', 'attempt': 1}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '2cd81d8f-3d3a-4614-81dc-0dfa4af8b6ae'}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '2cd81d8f-3d3a-4614-81dc-0dfa4af8b6ae'}, {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:19:19.1961891Z', 'done': True, 'done_reason': 'stop', 'total_duration': 33294046200, 'load_duration': 29351895200, 'prompt_eval_count': 231, 'prompt_eval_duration': 1253437000, 'eval_count': 42, 'eval_duration': 2669726000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ea1ce-8186-77a3-97ea-f0e7144e55e4-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '075de630-3066-481b-8b5f-8cba8d7ac36a', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 42, 'total_tokens': 273}}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '2cd81d8f-3d3a-4614-81dc-0dfa4af8b6ae'}, {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:19:19.1961891Z', 'done': True, 'done_reason': 'stop', 'total_duration': 33294046200, 'load_duration': 29351895200, 'prompt_eval_count': 231, 'prompt_eval_duration': 1253437000, 'eval_count': 42, 'eval_duration': 2669726000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ea1ce-8186-77a3-97ea-f0e7144e55e4-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '075de630-3066-481b-8b5f-8cba8d7ac36a', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 42, 'total_tokens': 273}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '516e624f-b966-478d-9743-c06ce4e4991c', 'tool_call_id': '075de630-3066-481b-8b5f-8cba8d7ac36a', 'artifact': None, 'status': 'success'}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '2cd81d8f-3d3a-4614-81dc-0dfa4af8b6ae'}, {'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:19:19.1961891Z', 'done': True, 'done_reason': 'stop', 'total_duration': 33294046200, 'load_duration': 29351895200, 'prompt_eval_count': 231, 'prompt_eval_duration': 1253437000, 'eval_count': 42, 'eval_duration': 2669726000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ea1ce-8186-77a3-97ea-f0e7144e55e4-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '075de630-3066-481b-8b5f-8cba8d7ac36a', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 42, 'total_tokens': 273}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '516e624f-b966-478d-9743-c06ce4e4991c', 'tool_call_id': '075de630-3066-481b-8b5f-8cba8d7ac36a', 'artifact': None, 'status': 'success'}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:19:25.8520836Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6612539500, 'load_duration': 756940500, 'prompt_eval_count': 263, 'prompt_eval_duration': 1037839000, 'eval_count': 49, 'eval_duration': 4806325000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ea1cf-03c6-7260-8839-0448f4b1c876-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 49, 'total_tokens': 312}}]}, id=None)

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="updates"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '019ea1cf-a356-7753-9743-25a7a243c82f', 'attempt': 1}, id=None)
# StreamPart(event='updates', data={'assistant': {'messages': [{'content': '', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:20:05.5713197Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4706713300, 'load_duration': 580196800, 'prompt_eval_count': 231, 'prompt_eval_duration': 496231000, 'eval_count': 44, 'eval_duration': 3611637000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ea1cf-a65c-76f0-a42d-ed56d737fc85-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '8d0bba20-8e5d-4281-b978-f195201dd53f', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 44, 'total_tokens': 275}}]}}, id=None)
# StreamPart(event='updates', data={'tools': {'messages': [{'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '034dce7a-9119-434e-a249-515d2be640d8', 'tool_call_id': '8d0bba20-8e5d-4281-b978-f195201dd53f', 'artifact': None, 'status': 'success'}]}}, id=None)
# StreamPart(event='updates', data={'assistant': {'messages': [{'content': 'The product of\u202f2\u202fand\u202f3 is\u202f**6**.', 'additional_kwargs': {}, 'response_metadata': {'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:20:13.2233623Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7618281100, 'load_duration': 609065200, 'prompt_eval_count': 263, 'prompt_eval_duration': 1010961000, 'eval_count': 47, 'eval_duration': 5982684000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'}, 'type': 'ai', 'name': None, 'id': 'lc_run--019ea1cf-b8e2-7d40-bfbf-6ece11f46a9c-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 47, 'total_tokens': 310}}]}}, id=None)

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={} response_metadata={} id='6bb37f0f-5fd0-4c13-80a4-a636485f9e56'
# =========================
# content='' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 231, 'output_tokens': 38, 'total_tokens': 269}} response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:20:53.3215586Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3638816400, 'load_duration': 563627900, 'prompt_eval_count': 231, 'prompt_eval_duration': 248462000, 'eval_count': 38, 'eval_duration': 2815974000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'} id='lc_run--019ea1d0-6510-7670-aef5-5d19c76415f8-0' tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': '18df0404-8ff4-4226-a5dd-3053eb80198d', 'type': 'tool_call'}] invalid_tool_calls=[]
# =========================
# content='6' name='multiply' id='639409c8-44f1-4c9a-a552-4914c5562e7d' tool_call_id='18df0404-8ff4-4226-a5dd-3053eb80198d'
# =========================
# content='Sure! The product of\u202f2\u202fand\u202f3 is **6**.' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 263, 'output_tokens': 49, 'total_tokens': 312}} response_metadata={'model': 'gpt-oss:20b', 'created_at': '2026-06-07T11:21:00.4378818Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7081604600, 'load_duration': 564580000, 'prompt_eval_count': 263, 'prompt_eval_duration': 991499000, 'eval_count': 49, 'eval_duration': 5515275000, 'logprobs': None, 'model_name': 'gpt-oss:20b', 'model_provider': 'ollama'} id='lc_run--019ea1d0-736b-7843-bcc7-0e154103caa1-0' tool_calls=[] invalid_tool_calls=[]
# =========================

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="updates"):
    messages = event.data.get('messages',None)
    print(messages)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# None
# =========================
# None
# =========================
# None
# =========================
# None
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can  [use `messages` mode](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event.event)
# Out:
# metadata
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/metadata
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# <!--You can dig further into the types [~here~](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages) [here](https://docs.langchain.com/oss/python/langgraph/concepts/langgraph_server). -->
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata and response_metadata.get("finish_reason"):
                    print(f"Response Metadata: Finish Reason - {response_metadata['finish_reason']}")                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 019ea1da-3722-79c3-a893-f4ef8cc06e30
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: 9105357f-736e-4191-8193-ac2c5e9e3252, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: 9105357f-736e-4191-8193-ac2c5e9e3252, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# AI: The
# --------------------------------------------------
# AI: The result
# --------------------------------------------------
# AI: The result of
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying 2
# --------------------------------------------------
# AI: The result of multiplying 2 by
# --------------------------------------------------
# AI: The result of multiplying 2 by
# --------------------------------------------------
# AI: The result of multiplying 2 by 3
# --------------------------------------------------
# AI: The result of multiplying 2 by 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 by 3 is **
# --------------------------------------------------
# AI: The result of multiplying 2 by 3 is **6
# --------------------------------------------------
# AI: The result of multiplying 2 by 3 is **6**
# --------------------------------------------------
# AI: The result of multiplying 2 by 3 is **6**.
# --------------------------------------------------
# AI: The result of multiplying 2 by 3 is **6**.
# --------------------------------------------------
# AI: The result of multiplying 2 by 3 is **6**.
# --------------------------------------------------
