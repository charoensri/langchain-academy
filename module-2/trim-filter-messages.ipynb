# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_openai

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# We'll use [LangSmith](https://docs.langchain.com/langsmith/home) for [tracing](https://docs.langchain.com/langsmith/observability-concepts).
#
# We'll log to a project, `langchain-academy`.

# %%
_set_env("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama

#llm = ChatOpenAI(model="gpt-4o")
llm = ChatOllama(model="gpt-oss:20b")
llm.invoke(messages)
# Out:
# AIMessage(content='That’s great! You already have a solid foundation with whales, so you’re ready to dive into the broader family of marine mammals. Below is a “menu” of the most interesting and ecologically important ocean mammals you might want to explore next, along with quick facts, what makes them unique, why they’re worth studying, and some pointers on where to find more in‑depth information.\n\n---\n\n## 1. Dolphins (Delphinidae)\n\n| Species | Notable Features | Research Angles |\n|---------|------------------|-----------------|\n| **Bottlenose dolphin (Tursiops truncatus)** | Highly social, complex vocal repertoire, “signature whistles.” | Acoustic communication; tool use (e.g., sponges). |\n| **Orca / Killer whale (Orcinus orca)** | Apex predator, matriarchal pods, diverse ecotypes (fish‑eaters, marine‑mammal‑eaters, etc.). | Cultural transmission; ecosystem impacts; human interactions. |\n| **Short‑finned pilot whale (Globicephala macrorhynchus)** | Unique “pilot‑wave” behavior, deep‑diving for squid. | Deep‑sea foraging strategies; cetacean cognition. |\n\n*Why they matter:* Dolphins are excellent bioindicators and are among the most charismatic marine mammals, drawing public interest and funding for marine conservation.\n\n---\n\n## 2. Porpoises (Phocoenidae)\n\n| Species | Highlights | Research Opportunities |\n|---------|------------|------------------------|\n| **Harbor porpoise (Phocoena phocoena)** | Smallest cetacean in temperate zones, “buzz” for echolocation. | Acoustic monitoring; effects of shipping noise. |\n| **Dall’s porpoise (Phocoenoides dalli)** | Unique “hump” in dorsal fin; deep‑diving in Arctic waters. | Climate change impacts on Arctic prey. |\n\n*Why study them:* Porpoises are often under‑represented in marine science yet share many ecological roles with dolphins.\n\n---\n\n## 3. Sirenians (Sea‑turtles & Turtles‑like)\n\n| Species | Traits | Research Topics |\n|---------|--------|-----------------|\n| **Manatee (Trichechus spp.)** | Herbivorous, slow‑moving, sensitive to thermal pollution. | Habitat mapping; impact of coastal development. |\n| **Dugong (Dugong dugon)** | Closely related to manatees, prefers seagrass beds in the Indo‑Pacific. | Seagrass ecosystem health; threats from fishing gear. |\n\n*Why they’re key:* Sirenians are “living fossils” that help us understand marine ecosystem stability and the role of large herbivores.\n\n---\n\n## 4. Pinnipeds (Seals, Sea Lions, Walruses)\n\n| Species | Key Facts | Study Ideas |\n|---------|-----------|-------------|\n| **Northern elephant seal (Mirounga angustirostris)** | Largest seal; extreme sexual dimorphism. | Hormonal regulation of breeding; climate impact on haul‑outs. |\n| **Harbor seal (Phoca vitulina)** | One of the most common seals worldwide. | Human–seal conflicts; disease monitoring. |\n| **Weddell seal (Leptonychotes weddellii)** | Lives almost entirely under Antarctic ice. | Cryosphere interactions; adaptation to cold. |\n| **Walrus (Odobenus rosmarus)** | Long tusks, massive body; feeds on benthic invertebrates. | Tusk development; ecosystem engineering. |\n\n*Why they’re fascinating:* Pinnipeds occupy both marine and terrestrial environments, making them natural “bridge species” for studying ecosystem connectivity.\n\n---\n\n## 5. Marine Otters (Lutrinae)\n\n| Species | Interesting Aspects | Potential Research |\n|---------|---------------------|--------------------|\n| **Sea otter (Enhydra lutris)** | Keystone species in kelp forests; uses tools to break shellfish. | Kelp forest resilience; human‑wildlife conflict. |\n| **Smooth‑water otter (Lutrogale perspicillata)** | Lives in mangroves and estuaries of Asia. | Mangrove ecosystem health; zoonotic disease risk. |\n\n*Why they’re relevant:* Otters are indicators of coastal health and are often a focal species for marine conservation education.\n\n---\n\n## 6. Lesser‑Known but Important Species\n\n| Group | Example | Why Study? |\n|-------|---------|------------|\n| **Beaked  ...

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Great to hear you’re diving into the world of ocean mammals! While whales are the most famous, the marine realm hosts a whole host of other mammals that are equally fascinating—and many of them are less well‑known, making them exciting subjects for deeper research. Below is a quick tour of the main groups, why they’re worth studying, and some ideas for where to start (books, documentaries, journals, and online resources).
#
# ---
#
# ## 1. **Dolphins (Delphinidae)**
# | Why Study Them? | Key Topics |
# |---|---|
# | **Advanced cognition** – social learning, tool use, culture. | *Echolocation* mechanics, *song* communication, *tool‑using* behaviors (e.g., humpback dolphins using sponges). |
# | **Human impact** – by‑catch, noise pollution, boat strikes. | *Marine noise effects* on acoustic navigation, *plastic ingestion*. |
# | **Conservation** – some species are critically endangered. | *Population genetics*, *habitat fragmentation*. |
#
# **Start‑ups**
# - *Book:* “**The Story of the Whale**” by John F. Hawkes (covers dolphins, but with a broader marine perspective).
# - *Docu:* “**The Dolphin's Song**” (PBS Nature).
# - *Journal:* *Marine Mammal Science* (focus on behavioral ecology).
#
# ---
#
# ## 2. **Porpoises (Phocoenidae)**
# Often confused with dolphins, but smaller and with a distinct “porpoise” echolocation click pattern.
#
# - **Why**: Less studied than dolphins, making them ripe for new discoveries.
# - **Research angles**: *Acoustic communication*, *population dynamics*, *human–porpoise interactions* (e.g., by‑catch in artisanal fisheries).
# - **Key species**: Harbor porpoise (*Phocoena phocoena*), Yangtze finless porpoise (*Neophocaena asiaeorientalis*).
#
# ---
#
# ## 3. **Manatees (Trichechidae) – Sea Gnus**
# | Why Study? | Topics |
# |---|---|
# | **Aquatic herbivory** – major impact on freshwater/estuarine ecosystems. | *Feeding ecology*, *sediment impact*, *riverine migration*. |
# | **Conservation** – highly endangered, often a “charismatic” species for freshwater conservation. | *Genetic diversity*, *human‑wildlife conflict* (e.g., boat strikes). |
#
# **Resources**
# - *Book:* “**Sea Turtles and Manatees: The Hidden Giants of the Water**” (PDF on Marine Conservation Society).
# - *Journal:* *Journal of Mammalogy* (has many manatee papers).
# - *Docu:* “**Manatee Mysteries**” (National Geographic).
#
# ---
#
# ## 4. **Dugongs (Dugongidae) – Sea Cow**
# Often considered the “slow‑moving cousins” of manatees but distinct.
#
# - **Why**: Highly specialized herbivores with a very limited range (Indian/Western Pacific).
# - **Research**: *Habitat use* (seagrass beds), *impact of coastal development*, *disease ecology*.
# - **Key facts**: Only three species; critically endangered in the Red Sea.
#
# **Start‑ups**
# - *Journal:* *Marine Biology* (articles on dugong population genetics).
# - *Book:* “**The Dugong’s World**” by T. J. B. and C. R. (accessible through university libraries).
# - *Docu:* “**The Secret Life of the Dugong**” (BBC).
#
# ---
#
# ## 5. **Seals (Phocidae) & Sea Lions (Otariidae)**
# | Why Study? | Topics |
# |---|---|
# | **Diverse habitats** – from Arctic to tropical. | *Physiological adaptations* (blubber metabolism), *migration patterns*, *reproductive cycles*. |
# | **Human interactions** – fishing competition, tourism. | *Human‑seal conflict*, *disease transmission* (e.g., leptospirosis). |
# | **Climate change** – impacts on ice habitat. | *Ice‑breaker* behavior of harp seals, *sea‑ice dependence*. |
#
# **Key Species**
# - *Harbor seal* (*Phoca vitulina*), *California sea lion* (*Zalophus californianus*), *Antarctic fur seal* (*Arctocephalus gazella*).
#
# **Resources**
# - *Book:* “**Seals and Sea Lions: A Natural History**” by C. J. M. M. (free pdf).
# - *Docu:* “**Seal of the Arctic**” (Discovery Channel).
# - *Journal:* *Coastal Management* (often features seal population studies).
#
# ---
#
# ## 6. **Walruses (Odobenus rosmarus)**
# Large, tusked ungulate‑like mammals that are a classic study of *social thermoregulation* and *hunting for benthic invertebrates*.
#
# - **Topics**: *Gregarious haul‑out behavior*, *tusk development*, *impact of hunting pressure* (historical and contemporary).
# - **Resource**: *Journal of the Marine Biological Association of the United Kingdom* – special issues on walruses.
#
# ---
#
# ## 7. **Marine Rodents – the Water Vole (Arvicola amphibius)**
# While not as flashy, they’re an excellent model for *mammalian adaptation to aquatic environments*.
#
# - **Why**: Provide insight into *evolutionary convergence* with pinnipeds.
# - **Research**: *Physiological thermoregulation*, *behavioral ecology*.
# - **Resource**: *Mammalian Biology* journal.
#
# ---
#
# ## 8. **Less‑Known Giants & Endangered Species**
# | Species | Why It’s Interesting |
# |---|---|
# | *Steller’s sea cow* (extinct) | Lessons on human‑induced extinction. |
# | *Giant river otter* (*Pteronura brasiliensis*) | Largest otter, keystone predator in Amazon. |
# | *Baiji* (Yangtze river dolphin) (extinct) | A cautionary tale of rapid habitat loss. |
# | *Spix’s disc dolphin* (*Lagenorhynchus spixii*) | One of the most endangered cetaceans in the world. |
#
# ---
#
# ## 9. **Cross‑Disciplinary Research Ideas**
#
# | Field | Marine Mammal Focus |
# |---|---|
# | **Genomics** | Comparative genomics of echolocation genes (e.g., *Sox2* and *Prestin*). |
# | **Acoustics** | Passive acoustic monitoring of harbor porpoise populations. |
# | **Ecotoxicology** | Plastic ingestion in dugongs and sea turtles. |
# | **Climate Science** | Modeling the future distribution of polar bears and walruses under sea‑ice decline. |
# | **Behavioral Ecology** | Cultural transmission of hunting techniques in dolphin pods. |
#
# ---
#
# ## 10. **Where to Find Primary Sources**
#
# 1. **Databases**
#    - *Web of Science*, *Scopus*, *Google Scholar* (use keywords like “marine mammal ecology” or specific species).
#    - *Marine Mammal Database (MMDB)* – for distribution maps and status.
#
# 2. **Open‑Access Journals**
#    - *PLOS ONE* (marine mammal studies).
#    - *Frontiers in Ecology and the Environment*.
#    - *Marine Mammal Science* (most comprehensive).
#
# 3. **Institutional Repositories**
#    - *National Oceanic and Atmospheric Administration (NOAA)* – data sets and reports.
#    - *Marine Mammal Commission* – policy briefs.
#
# 4. **Books & Reviews**
#    - *“Marine Mammals: Evolutionary Biology”* by J. R. P. (Oxford).
#    - *“The Encyclopedia of Marine Mammals”* (Springer).
#    - *“Echolocation and Auditory Neuroscience of Cetaceans”* (Science Advances).
#
# ---
#
# ## 11. **Suggested Project Ideas (for a thesis or independent study)**
#
# 1. **Echolocation Soundscape Mapping** – Using autonomous recording units (ARUs) to map dolphin/porpoise presence across a coastal bay.
# 2. **Impact of Ship Traffic on Seal Behavior** – GPS tracking and acoustic monitoring of harbor seals near a busy harbor.
# 3. **Genetic Rescue Feasibility** – Assessing genetic diversity in the critically endangered Spix’s disc dolphin using non‑invasive hair sampling.
# 4. **Climate Change and Seagrass‑Dependent Dugong Populations** – Modelling seagrass distribution under future sea‑temperature scenarios.
# 5. **Human–Wildlife Conflict Mitigation** – Designing educational outreach for fishermen to reduce by‑catch of marine mammals.
#
# ---
#
# ### Quick Takeaway
#
# - **Whales** are great, but the marine world is full of diverse mammals: dolphins, porpoises, manatees, dugongs, seals, sea lions, walruses, and even marine rodents.
# - Each group offers unique angles: **cognition & culture** (dolphins), **human impact** (manatees & dugongs), **climate vulnerability** (polar species), **physiological adaptation** (seals, otters).
# - Start by picking a species or theme that sparks your curiosity, then dive into the rich literature and data available from open‑access journals and marine conservation databases.
#
# Feel free to let me know which species or topic catches your eye, and I can help you drill down into more specific research questions or literature recommendations!

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Great that you already know a bit about whales! Marine mammals are a fascinating and diverse group—beyond the large cetaceans there’s a whole spectrum of species that live in the ocean, brackish water, and even in freshwater rivers. Below is a quick “menu” of marine mammal families you might consider adding to your research, along with what makes each group special, why they’re worth studying, and some starter resources.
#
# | Group | Representative species | Key traits / what’s interesting | Why it matters (research & conservation) | Suggested starting points |
# |-------|------------------------|---------------------------------|----------------------------------------|---------------------------|
# | **Delphinidae – Dolphins & Porpoises** | Bottlenose dolphin, Common dolphin, Harbor porpoise | Highly social, complex vocalizations, advanced cognition, echolocation | Behavioral ecology, acoustic monitoring, human‑wildlife conflict (boat strikes, fishing nets) | *“Dolphins: A Guide to the Species”* by S. P. Johnson & D. M. G. H. (2022) |
# | **Phocoenidae – Porpoises** | Harbour porpoise, Dall’s porpoise | Small, elusive, short‑lived fluke; often misidentified | Biodiversity assessment, habitat mapping, climate‑impact on prey | *Porpoise Conservation* – IUCN (2023) |
# | **Otariidae – Sea Lions & Fur Seals** | California sea lion, Steller sea lion, Japanese sea lion | Eared, agile on land & water; breeding colonies on cliffs | Population monitoring, disease surveillance (e.g., leptospirosis), human interaction | *“Sea Lions: Biology and Conservation”* (Springer 2021) |
# | **Phocidae – True Seals** | Harbor seal, Elephant seal, Weddell seal | Lack external ear flaps, diverse habitats (tropical to polar) | Climate‑change impact on ice‑dependent species, haul‑out site dynamics | *“Seals of the World”* (National Geographic 2019) |
# | **Zalophidae – Walruses** | Northern walrus | Massive tusks, benthic feeding, complex social structure | Marine mammal ecosystem role, fisheries interactions, climate‑induced habitat loss | *Walrus Science Review* (Marine Mammal Science 2022) |
# | **Trichechidae – Manatees** | West Indian manatee, Amazonian manatee, West African manatee | Herbivorous, freshwater & estuarine habitats, highly threatened | Water quality indicators, human‑induced mortality (tides, collisions) | *“The Manatee’s Life”* by C. J. Smith (2018) |
# | **Dugongidae – Dugongs & Seals (sea cows)** | Dugong | Southern hemisphere only; feeds on seagrass meadows | Ecosystem engineers of seagrass beds; threatened by habitat loss | *“Dugong Conservation”* (IUCN 2020) |
# | **Monodontidae – Beluga & Narwhal** | Beluga whale, Narwhal | Arctic specialists, “sea canaries”; narwhal’s iconic tusk | Climate change, shipping noise, indigenous communities’ subsistence | *“Arctic Marine Mammals”* (Nature 2021) |
# | **Pinniped–Misc. (e.g., sea otters)** | Sea otter | Keystone predator of kelp forests, preys on mollusks | Kelp‑forest dynamics, predator‑prey interactions | *“Sea Otters”* (University of Washington Press 2016) |
# | **Cetacea–Other families (e.g., Balaenopteridae)** | Humpback whale, Fin whale | Migratory, baleen filter feeders, song communication | Migration routes, climate impact on plankton, acoustic communication | *“Whale Migration and Climate”* (Science 2023) |
# | **Freshwater & Brackish species** | Hippopotamus (semi‑aquatic), River dolphins (Indus, Ganges, Yangtze) | Rare aquatic mammals living in rivers & estuaries | Endangered river dolphin conservation, ecosystem health indicators | *“River Dolphins”* (Oryx 2019) |
#
# ---
#
# ## How to Dive Deeper
#
# ### 1. **Define a Focus Area**
# - **Behavior & Ecology**: e.g., social structure of bottlenose dolphins, hunting tactics of walruses.
# - **Physiology & Adaptation**: e.g., diving physiology of elephant seals, thermoregulation in sea otters.
# - **Conservation & Human Interaction**: e.g., the impact of fisheries on harbor porpoises, tourism effects on sea lion colonies.
#
# ### 2. **Key Data Sources**
# | Type | Example Resources |
# |------|-------------------|
# | Peer‑reviewed journals | *Marine Mammal Science*, *Journal of Cetacean Research & Management*, *IUCN Red List* |
# | Field studies & monitoring | NOAA Marine Mammal Protection Program, IUCN marine mammal assessment teams |
# | Databases | OBIS (Ocean Biogeographic Information System), GBIF (Global Biodiversity Information Facility) |
# | Books & Guides | The “Mammal Species of the World” database, “Marine Mammal Identification Guides” |
# | Outreach & NGOs | Whale and Dolphin Conservation, World Wildlife Fund (WWF), Sea Shepherd, local conservation groups |
#
# ### 3. **Potential Projects & Questions**
# | Topic | Example Question | Why it’s cool |
# |-------|------------------|---------------|
# | Acoustic monitoring | How does anthropogenic noise affect beluga whale communication? | Non‑invasive, tech‑driven research |
# | Climate change | How are seal haul‑out distributions shifting with sea‑ice loss? | Links to global climate models |
# | Disease ecology | What is the prevalence of *Leptospira* in harbor seal populations? | Human‑health implications |
# | Genetics & evolution | What does the genome of the dugong reveal about its ancestral link to manatees? | Evolutionary history |
# | Anthropogenic threats | How effective are “seal‑friendly” fishing gear modifications? | Mitigation strategies |
#
# ### 4. **Next‑Step Checklist**
# 1. **Pick a species or family** that intrigues you.
# 2. **Gather foundational literature** (reviews, recent papers, species accounts).
# 3. **Identify a research gap** or a pressing conservation question.
# 4. **Consider interdisciplinary angles** (e.g., combining acoustic monitoring with satellite telemetry).
# 5. **Reach out to experts**—email a specialist or attend a marine mammal conference.
# 6. **Plan a field or data‑analysis project**—or simply create a detailed species profile.
#
# ---
#
# ## Quick‑Start Resources
#
# | Category | Title | Why It’s Handy |
# |----------|-------|----------------|
# | **Field Guides** | *“Marine Mammals: A Field Guide”* (IUCN, 2019) | Identification in the field. |
# | **Acoustics** | *“Marine Mammal Bioacoustics”* (R. J. B. C. Jones, 2020) | Basics of sound in marine mammals. |
# | **Conservation** | *“Marine Mammal Conservation”* (S. L. L. 2021) | Global threats & policy. |
# | **Data Analysis** | *“Ecological Modeling with R”* (Harvard Press 2023) | Tools for spatial analysis. |
# | **Online Database** | **OBIS** – [obis.org](https://obis.org) | Occurrence data & distribution maps. |
# | **Open‑Access Journals** | *PeerJ* (marine mammal articles), *Frontiers in Marine Science* | Free access to cutting‑edge research. |
#
# ---
#
# ### Bottom Line
#
# You’ve already got a strong starting point with whales. Expanding into dolphins, seals, otters, and even freshwater species like river dolphins and manatees will give you a richer picture of how marine mammals adapt to diverse habitats and face human‑related pressures. Pick a focus that excites you—whether it’s the acoustic mystique of belugas or the ecological role of sea otters—and you’ll be on a path to some truly rewarding research! If you need help narrowing down topics or finding datasets, just let me know.

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Great that you already know a bit about whales! Marine mammals are a fascinating and diverse group—beyond the large cetaceans there’s a whole spectrum of species that live in the ocean, brackish water, and even in freshwater rivers. Below is a quick “menu” of marine mammal families you might consider adding to your research, along with what makes each group special, why they’re worth studying, and some starter resources.
#
# | Group | Representative species | Key traits / what’s interesting | Why it matters (research & conservation) | Suggested starting points |
# |-------|------------------------|---------------------------------|----------------------------------------|---------------------------|
# | **Delphinidae – Dolphins & Porpoises** | Bottlenose dolphin, Common dolphin, Harbor porpoise | Highly social, complex vocalizations, advanced cognition, echolocation | Behavioral ecology, acoustic monitoring, human‑wildlife conflict (boat strikes, fishing nets) | *“Dolphins: A Guide to the Species”* by S. P. Johnson & D. M. G. H. (2022) |
# | **Phocoenidae – Porpoises** | Harbour porpoise, Dall’s porpoise | Small, elusive, short‑lived fluke; often misidentified | Biodiversity assessment, habitat mapping, climate‑impact on prey | *Porpoise Conservation* – IUCN (2023) |
# | **Otariidae – Sea Lions & Fur Seals** | California sea lion, Steller sea lion, Japanese sea lion | Eared, agile on land & water; breeding colonies on cliffs | Population monitoring, disease surveillance (e.g., leptospirosis), human interaction | *“Sea Lions: Biology and Conservation”* (Springer 2021) |
# | **Phocidae – True Seals** | Harbor seal, Elephant seal, Weddell seal | Lack external ear flaps, diverse habitats (tropical to polar) | Climate‑change impact on ice‑dependent species, haul‑out site dynamics | *“Seals of the World”* (National Geographic 2019) |
# | **Zalophidae – Walruses** | Northern walrus | Massive tusks, benthic feeding, complex social structure | Marine mammal ecosystem role, fisheries interactions, climate‑induced habitat loss | *Walrus Science Review* (Marine Mammal Science 2022) |
# | **Trichechidae – Manatees** | West Indian manatee, Amazonian manatee, West African manatee | Herbivorous, freshwater & estuarine habitats, highly threatened | Water quality indicators, human‑induced mortality (tides, collisions) | *“The Manatee’s Life”* by C. J. Smith (2018) |
# | **Dugongidae – Dugongs & Seals (sea cows)** | Dugong | Southern hemisphere only; feeds on seagrass meadows | Ecosystem engineers of seagrass beds; threatened by habitat loss | *“Dugong Conservation”* (IUCN 2020) |
# | **Monodontidae – Beluga & Narwhal** | Beluga whale, Narwhal | Arctic specialists, “sea canaries”; narwhal’s iconic tusk | Climate change, shipping noise, indigenous communities’ subsistence | *“Arctic Marine Mammals”* (Nature 2021) |
# | **Pinniped–Misc. (e.g., sea otters)** | Sea otter | Keystone predator of kelp forests, preys on mollusks | Kelp‑forest dynamics, predator‑prey interactions | *“Sea Otters”* (University of Washington Press 2016) |
# | **Cetacea–Other families (e.g., Balaenopteridae)** | Humpback whale, Fin whale | Migratory, baleen filter feeders, song communication | Migration routes, climate impact on plankton, acoustic communication | *“Whale Migration and Climate”* (Science 2023) |
# | **Freshwater & Brackish species** | Hippopotamus (semi‑aquatic), River dolphins (Indus, Ganges, Yangtze) | Rare aquatic mammals living in rivers & estuaries | Endangered river dolphin conservation, ecosystem health indicators | *“River Dolphins”* (Oryx 2019) |
#
# ---
#
# ## How to Dive Deeper
#
# ### 1. **Define a Focus Area**
# - **Behavior & Ecology**: e.g., social structure of bottlenose dolphins, hunting tactics of walruses.
# - **Physiology & Adaptation**: e.g., diving physiology of elephant seals, thermoregulation in sea otters.
# - **Conservation & Human Interaction**: e.g., the impact of fisheries on harbor porpoises, tourism effects on sea lion colonies.
#
# ### 2. **Key Data Sources**
# | Type | Example Resources |
# |------|-------------------|
# | Peer‑reviewed journals | *Marine Mammal Science*, *Journal of Cetacean Research & Management*, *IUCN Red List* |
# | Field studies & monitoring | NOAA Marine Mammal Protection Program, IUCN marine mammal assessment teams |
# | Databases | OBIS (Ocean Biogeographic Information System), GBIF (Global Biodiversity Information Facility) |
# | Books & Guides | The “Mammal Species of the World” database, “Marine Mammal Identification Guides” |
# | Outreach & NGOs | Whale and Dolphin Conservation, World Wildlife Fund (WWF), Sea Shepherd, local conservation groups |
#
# ### 3. **Potential Projects & Questions**
# | Topic | Example Question | Why it’s cool |
# |-------|------------------|---------------|
# | Acoustic monitoring | How does anthropogenic noise affect beluga whale communication? | Non‑invasive, tech‑driven research |
# | Climate change | How are seal haul‑out distributions shifting with sea‑ice loss? | Links to global climate models |
# | Disease ecology | What is the prevalence of *Leptospira* in harbor seal populations? | Human‑health implications |
# | Genetics & evolution | What does the genome of the dugong reveal about its ancestral link to manatees? | Evolutionary history |
# | Anthropogenic threats | How effective are “seal‑friendly” fishing gear modifications? | Mitigation strategies |
#
# ### 4. **Next‑Step Checklist**
# 1. **Pick a species or family** that intrigues you.
# 2. **Gather foundational literature** (reviews, recent papers, species accounts).
# 3. **Identify a research gap** or a pressing conservation question.
# 4. **Consider interdisciplinary angles** (e.g., combining acoustic monitoring with satellite telemetry).
# 5. **Reach out to experts**—email a specialist or attend a marine mammal conference.
# 6. **Plan a field or data‑analysis project**—or simply create a detailed species profile.
#
# ---
#
# ## Quick‑Start Resources
#
# | Category | Title | Why It’s Handy |
# |----------|-------|----------------|
# | **Field Guides** | *“Marine Mammals: A Field Guide”* (IUCN, 2019) | Identification in the field. |
# | **Acoustics** | *“Marine Mammal Bioacoustics”* (R. J. B. C. Jones, 2020) | Basics of sound in marine mammals. |
# | **Conservation** | *“Marine Mammal Conservation”* (S. L. L. 2021) | Global threats & policy. |
# | **Data Analysis** | *“Ecological Modeling with R”* (Harvard Press 2023) | Tools for spatial analysis. |
# | **Online Database** | **OBIS** – [obis.org](https://obis.org) | Occurrence data & distribution maps. |
# | **Open‑Access Journals** | *PeerJ* (marine mammal articles), *Frontiers in Marine Science* | Free access to cutting‑edge research. |
#
# ---
#
# ### Bottom Line
#
# You’ve already got a strong starting point with whales. Expanding into dolphins, seals, otters, and even freshwater species like river dolphins and manatees will give you a richer picture of how marine mammals adapt to diverse habitats and face human‑related pressures. Pick a focus that excites you—whether it’s the acoustic mystique of belugas or the ecological role of sea otters—and you’ll be on a path to some truly rewarding research! If you need help narrowing down topics or finding datasets, just let me know.
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Great that you already know a bit about whales! Marine mammals are a fascinating and diverse group—beyond the large cetaceans there’s a whole spectrum of species that live in the ocean, brackish water, and even in freshwater rivers. Below is a quick “menu” of marine mammal families you might consider adding to your research, along with what makes each group special, why they’re worth studying, and some starter resources.
#
# | Group | Representative species | Key traits / what’s interesting | Why it matters (research & conservation) | Suggested starting points |
# |-------|------------------------|---------------------------------|----------------------------------------|---------------------------|
# | **Delphinidae – Dolphins & Porpoises** | Bottlenose dolphin, Common dolphin, Harbor porpoise | Highly social, complex vocalizations, advanced cognition, echolocation | Behavioral ecology, acoustic monitoring, human‑wildlife conflict (boat strikes, fishing nets) | *“Dolphins: A Guide to the Species”* by S. P. Johnson & D. M. G. H. (2022) |
# | **Phocoenidae – Porpoises** | Harbour porpoise, Dall’s porpoise | Small, elusive, short‑lived fluke; often misidentified | Biodiversity assessment, habitat mapping, climate‑impact on prey | *Porpoise Conservation* – IUCN (2023) |
# | **Otariidae – Sea Lions & Fur Seals** | California sea lion, Steller sea lion, Japanese sea lion | Eared, agile on land & water; breeding colonies on cliffs | Population monitoring, disease surveillance (e.g., leptospirosis), human interaction | *“Sea Lions: Biology and Conservation”* (Springer 2021) |
# | **Phocidae – True Seals** | Harbor seal, Elephant seal, Weddell seal | Lack external ear flaps, diverse habitats (tropical to polar) | Climate‑change impact on ice‑dependent species, haul‑out site dynamics | *“Seals of the World”* (National Geographic 2019) |
# | **Zalophidae – Walruses** | Northern walrus | Massive tusks, benthic feeding, complex social structure | Marine mammal ecosystem role, fisheries interactions, climate‑induced habitat loss | *Walrus Science Review* (Marine Mammal Science 2022) |
# | **Trichechidae – Manatees** | West Indian manatee, Amazonian manatee, West African manatee | Herbivorous, freshwater & estuarine habitats, highly threatened | Water quality indicators, human‑induced mortality (tides, collisions) | *“The Manatee’s Life”* by C. J. Smith (2018) |
# | **Dugongidae – Dugongs & Seals (sea cows)** | Dugong | Southern hemisphere only; feeds on seagrass meadows | Ecosystem engineers of seagrass beds; threatened by habitat loss | *“Dugong Conservation”* (IUCN 2020) |
# | **Monodontidae – Beluga & Narwhal** | Beluga whale, Narwhal | Arctic specialists, “sea canaries”; narwhal’s iconic tusk | Climate change, shipping noise, indigenous communities’ subsistence | *“Arctic Marine Mammals”* (Nature 2021) |
# | **Pinniped–Misc. (e.g., sea otters)** | Sea otter | Keystone predator of kelp forests, preys on mollusks | Kelp‑forest dynamics, predator‑prey interactions | *“Sea Otters”* (University of Washington Press 2016) |
# | **Cetacea–Other families (e.g., Balaenopteridae)** | Humpback whale, Fin whale | Migratory, baleen filter feeders, song communication | Migration routes, climate impact on plankton, acoustic communication | *“Whale Migration and Climate”* (Science 2023) |
# | **Freshwater & Brackish species** | Hippopotamus (semi‑aquatic), River dolphins (Indus, Ganges, Yangtze) | Rare aquatic mammals living in rivers & estuaries | Endangered river dolphin conservation, ecosystem health indicators | *“River Dolphins”* (Oryx 2019) |
#
# ---
#
# ## How to Dive Deeper
#
# ### 1. **Define a Focus Area**
# - **Behavior & Ecology**: e.g., social structure of bottlenose dolphins, hunting tactics of walruses.
# - **Physiology & Adaptation**: e.g., diving physiology of elephant seals, thermoregulation in sea otters.
# - **Conservation & Human Interaction**: e.g., the impact of fisheries on harbor porpoises, tourism effects on sea lion colonies.
#
# ### 2. **Key Data Sources**
# | Type | Example Resources |
# |------|-------------------|
# | Peer‑reviewed journals | *Marine Mammal Science*, *Journal of Cetacean Research & Management*, *IUCN Red List* |
# | Field studies & monitoring | NOAA Marine Mammal Protection Program, IUCN marine mammal assessment teams |
# | Databases | OBIS (Ocean Biogeographic Information System), GBIF (Global Biodiversity Information Facility) |
# | Books & Guides | The “Mammal Species of the World” database, “Marine Mammal Identification Guides” |
# | Outreach & NGOs | Whale and Dolphin Conservation, World Wildlife Fund (WWF), Sea Shepherd, local conservation groups |
#
# ### 3. **Potential Projects & Questions**
# | Topic | Example Question | Why it’s cool |
# |-------|------------------|---------------|
# | Acoustic monitoring | How does anthropogenic noise affect beluga whale communication? | Non‑invasive, tech‑driven research |
# | Climate change | How are seal haul‑out distributions shifting with sea‑ice loss? | Links to global climate models |
# | Disease ecology | What is the prevalence of *Leptospira* in harbor seal populations? | Human‑health implications |
# | Genetics & evolution | What does the genome of the dugong reveal about its ancestral link to manatees? | Evolutionary history |
# | Anthropogenic threats | How effective are “seal‑friendly” fishing gear modifications? | Mitigation strategies |
#
# ### 4. **Next‑Step Checklist**
# 1. **Pick a species or family** that intrigues you.
# 2. **Gather foundational literature** (reviews, recent papers, species accounts).
# 3. **Identify a research gap** or a pressing conservation question.
# 4. **Consider interdisciplinary angles** (e.g., combining acoustic monitoring with satellite telemetry).
# 5. **Reach out to experts**—email a specialist or attend a marine mammal conference.
# 6. **Plan a field or data‑analysis project**—or simply create a detailed species profile.
#
# ---
#
# ## Quick‑Start Resources
#
# | Category | Title | Why It’s Handy |
# |----------|-------|----------------|
# | **Field Guides** | *“Marine Mammals: A Field Guide”* (IUCN, 2019) | Identification in the field. |
# | **Acoustics** | *“Marine Mammal Bioacoustics”* (R. J. B. C. Jones, 2020) | Basics of sound in marine mammals. |
# | **Conservation** | *“Marine Mammal Conservation”* (S. L. L. 2021) | Global threats & policy. |
# | **Data Analysis** | *“Ecological Modeling with R”* (Harvard Press 2023) | Tools for spatial analysis. |
# | **Online Database** | **OBIS** – [obis.org](https://obis.org) | Occurrence data & distribution maps. |
# | **Open‑Access Journals** | *PeerJ* (marine mammal articles), *Frontiers in Marine Science* | Free access to cutting‑edge research. |
#
# ---
#
# ### Bottom Line
#
# You’ve already got a strong starting point with whales. Expanding into dolphins, seals, otters, and even freshwater species like river dolphins and manatees will give you a richer picture of how marine mammals adapt to diverse habitats and face human‑related pressures. Pick a focus that excites you—whether it’s the acoustic mystique of belugas or the ecological role of sea otters—and you’ll be on a path to some truly rewarding research! If you need help narrowing down topics or finding datasets, just let me know.
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# ### Narwhals – The Unicorns of the Sea
#
# | Category | Key Facts |
# |----------|-----------|
# | **Scientific name** | *Monodon monoceros* |
# | **Family** | Odobenidae (walruses, manatees, dugongs) |
# | **Average size** | 4–6 m (13–20 ft) long, 1.5–2.5 m (5–8 ft) tall at the shoulder |
# | **Weight** | 400–700 kg (880–1,540 lb) |
# | **Lifespan** | 30–45 years (some reports of >50 years) |
# | **Habitat** | Arctic and sub‑arctic waters of the Canadian, Greenland, Russian, and Norwegian Seas; typically found in sea‑ice‑covered zones at depths of 10–200 m. |
#
# ---
#
# ## 1.  The Legendary “Unicorn” Tusk
#
# - **What it is**: The male narwhal’s most famous feature is a long, spiral tusk—really a protruding tooth—that can reach 2–3 m (6–10 ft) in length.
# - **Structure**: The tusk is an elongated canine filled with a pulp cavity and a network of blood vessels, making it both a sensory organ and a tool.
# - **Function**: Scientists believe the tusk is used for:
#   - **Sexual selection**: Males with larger, straighter tusks are often more dominant and successful in attracting females.
#   - **Social interactions**: The tusk can be used to establish dominance, explore objects, and, in some rare observations, for tactile communication.
#   - **Sensory**: The blood vessels allow the tusk to detect changes in temperature, pressure, and chemical signals—essential in the murky Arctic waters.
#
# - **Female narwhals**: Usually lack tusks; when present, the female’s tusk is shorter and straighter.
#
# ---
#
# ## 2.  Physical and Biological Adaptations
#
# | Feature | Arctic Advantage |
# |---------|-----------------|
# | **Blubber** | 30–50 cm thick; stores energy and insulates against sub‑freezing waters. |
# | **Large, powerful flippers** | Enable powerful thrusts and agile turns in ice‑bound habitats. |
# | **Reduced external ear canal** | Minimizes heat loss. |
# | **Large dorsal fin** | Helps stabilize the long, laterally compressed body. |
# | **Pulsatile respiration** | Narwhals can hold breath for up to 15 minutes (average ~4 min) and can dive to depths >1,000 m in extreme cases. |
#
# ---
#
# ## 3.  Diet & Feeding Strategy
#
# - **Primary prey**: Antarctic cod, Arctic cod, capelin, herring, and sometimes small seals or walrus carcasses.
# - **Method**: Narwhals use their sensitive tusk to probe the sea floor for hidden prey. Once located, they use a rapid, suction‑like feeding stroke—pushing water out while swallowing a “bunch” of prey at once.
# - **Seasonal shift**: In winter, they feed mainly on benthic fish; in summer, they may move to shallower waters and consume more pelagic species.
#
# ---
#
# ## 4.  Reproductive Life Cycle
#
# | Stage | Details |
# |-------|---------|
# | **Mating season** | March–April (in the sub‑arctic) when sea‑ice begins to melt. |
# | **Mating strategy** | Males engage in “tusk‑rubbing” and vocal duels; the strongest pair typically mate. |
# | **Gestation** | 13–15 months, giving birth to a single calf in July–August. |
# | **Calf development** | Calves stay close to the mother for up to 4–5 years; they learn hunting techniques by watching their mothers. |
# | **Social structure** | Typically live in small groups of 5–20 individuals; often structured around a dominant male and a female’s immediate offspring. |
#
# ---
#
# ## 5.  Communication & Vocalizations
#
# - Narwhals produce a wide range of sounds: clicks, whistles, and low‑frequency “barks.”
# - **Clicks**: Used for echolocation to navigate icy waters and locate prey.
# - **Whistles**: Thought to encode individual identity, much like a whale’s “signature.”
# - **Singing**: Some populations have been observed making rhythmic sequences—still a topic of active research.
#
# ---
#
# ## 6.  Conservation Status
#
# | Organization | Status | Notes |
# |--------------|--------|-------|
# | **IUCN Red List** | Near Threatened | Population estimates: ~30,000 individuals. |
# | **CITES** | Appendix II | International trade regulated to prevent overexploitation. |
# | **National Laws** | Varies: Canada’s **Marine Mammal Regulations** (Marine Mammal Protection Act) and Greenland’s **Conservation of Marine Mammals Act** provide protection. |
#
# ### Threats
# 1. **Climate change**: Reduced sea ice affects breeding grounds and food availability.
# 2. **Human activities**:
#    - **Fishing gear entanglement** (though less common than for other cetaceans).
#    - **Industrial noise**: Disrupts echolocation and communication.
# 3. **Predation**: Historically by polar bears and killer whales, but largely mitigated.
#
# ### Conservation Measures
# - **Protected areas**: Several national parks in Canada and Greenland overlap narwhal habitats.
# - **Research initiatives**: Acoustic monitoring, satellite tagging, and genetic studies to understand population dynamics.
# - **Community engagement**: Indigenous groups monitor narwhal movements and incorporate traditional ecological knowledge into management plans.
#
# ---
#
# ## 7.  Cultural Significance & Myths
#
# | Culture | Narwhal Significance |
# |---------|---------------------|
# | **Indigenous Arctic** | Viewed as a symbol of strength and perseverance; used in folklore. |
# | **European explorers** | Misidentified as “unicorns” in the 16th–18th centuries; their tusks were traded for luxury items and mythical “magic.” |
# | **Modern pop culture** | Featured in *“The Thing”* (1982), *“Star Trek: Voyager”*, and various documentary series (e.g., *“Arctic Currents”*). |
#
# ---
#
# ## 8.  Fun & Curious Facts
#
# - **Tusk “breathing”**: The tusk’s blood vessels allow it to “breathe” through the tip; when the narwhal is on the surface, the tip is often warm and moist.
# - **Tusk growth**: The tusk grows at about 5–7 cm per year and continues to grow throughout the narwhal’s life.
# - **Historical trade**: In the 18th century, a 6‑ft narwhal tusk sold at auction for a record price—some say over £1,000!
# - **Ice‑bound diet**: Narwhals can “hunt” beneath the ice by blowing a bubble of water above the ice to create a bubble “probe”—an example of behavioral adaptation to extreme environments.
#
# ---
#
# ## 9.  How to Spot a Narwhal
#
# | Condition | Tips |
# |-----------|------|
# | **Season** | Late winter/early spring when sea ice is thinning. |
# | **Location** | Near the mouths of the Churchill River (Canada) or the Kara Sea (Russia). |
# | **Visual cues** | A small, gray‑black body with a long, spiraled tusk (if male) emerging from the head; sleek fins; occasional flashes of white on the sides. |
# | **Tools** | Binoculars (30‑70×), GPS coordinates, and knowledge of typical depth ranges. |
#
# ---
#
# ## 10.  Suggested Resources for Further Reading
#
# - **Books**
#   - *Narwhals: The Life and Mysteries of the Unicorn of the Sea* by John R. Smith (2020).
#   - *Arctic Ocean Life* (2021), chapters on mysticetes.
#
# - **Documentaries**
#   - *BBC Earth: "Narwhals – The Unicorn of the Arctic"* (2022).
#   - *National Geographic: “Inside the Arctic – Narwhal”* (2023).
#
# - **Scientific Articles**
#   - “The Tusk of the Narwhal: A Morphological and Sensory Analysis” – *Journal of Marine Biology*, 2019.
#   - “Population Dynamics of Narwhals in Greenland” – *Arctic Science Review*, 2021.
#
# - **Online Databases**
#   - **Ocean Biogeographic Information System (OBIS)** – mapping narwhal sightings.
#   - **Marine Mammal Center** – up-to-date conservation status.
#
# ---
#
# ### Final Thought
#
# Narwhals embody the mysteries of the Arctic: elegant, elusive, and full of hidden wonders. While the legend of the unicorn may have started as a misinterpretation, it reminds us that nature often has its own stories—ones that scientists, indigenous peoples, and curious minds are still uncovering. Whether you’re a marine biologist, a nature documentary fan, or simply a lover of mythical creatures, the narwhal offers a tangible glimpse into a world where the line between myth and reality is as fluid as the sea itself.

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://docs.langchain.com/oss/python/langgraph/add-memory#trim-messages), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
def simple_token_counter(messages):
    return sum(len(m.content.split()) for m in messages)

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            #token_counter=ChatOpenAI(model="gpt-4o"),
            #token_counter=ChatOllama(model="gpt-oss:20b"),
            token_counter=simple_token_counter,
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# %pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: transformers in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (4.54.1)
# Requirement already satisfied: filelock in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (3.19.1)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\chars1\AppData\Roaming\Python\Python313\site-packages (from requests->transformers) (2025.7.9)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.4 kB ? eta -:--:--
#    ---------------------------------------- 566.4/566.4 kB 7.2 MB/s  0:00:00
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.13.0
#     Uninstalling huggingface_hub-1.13.0:
#       Successfully uninstalled huggingface_hub-1.13.0
# Successfully installed huggingface-hub-0.36.2
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            #token_counter=ChatOpenAI(model="gpt-4o"),
            #token_counter=ChatOllama(model="gpt-oss:20b"),
            token_counter=simple_token_counter,
            allow_partial=False
        )
# Out:
# [HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
